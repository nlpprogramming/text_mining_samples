# %%
# !git clone https://git.uibk.ac.at/csak8736/gvdb2021-code.git
# Out:
# Cloning into 'gvdb2021-code'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 24 (delta 3), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (24/24), done.

# %%
# !pip install poetry
# Out:
# ...
#      |████████████████████████████████| 175 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 54 kB 3.3 MB/s
# ...
#      |████████████████████████████████| 91 kB 13.2 MB/s
# ...
#      |████████████████████████████████| 424 kB 67.8 MB/s
# ...
#      |████████████████████████████████| 40 kB 7.4 MB/s
# ...
#      |████████████████████████████████| 8.6 MB 57.0 MB/s
# ...
#      |████████████████████████████████| 54 kB 3.3 MB/s
# ...
#      |████████████████████████████████| 3.6 MB 58.1 MB/s
# ...
#      |████████████████████████████████| 461 kB 73.4 MB/s
# ...
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.10.1
#     Uninstalling importlib-metadata-4.10.1:
#       Successfully uninstalled importlib-metadata-4.10.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
# ...

# %%
# !cd ./gvdb2021-code && poetry install
# Out:
# Creating virtualenv dtgrams-GUdQ5l65-py3.7 in /root/.cache/pypoetry/virtualenvs
# Installing dependencies from lock file
#
# Package operations: 154 installs, 0 updates, 0 removals
#
#   • Installing ipython-genutils (0.2.0): Pending...
#   • Installing typing-extensions (3.7.4.3): Pending...
#   • Installing zipp (3.4.1): Pending...
#   • Installing typing-extensions (3.7.4.3): Pending...
#   • Installing zipp (3.4.1): Pending...
#   • Installing ipython-genutils (0.2.0): Downloading... 0%
#   • Installing typing-extensions (3.7.4.3): Pending...
#   • Installing zipp (3.4.1): Pending...
#   • Installing typing-extensions (3.7.4.3): Pending...
#   • Installing zipp (3.4.1): Pending...
#   • Installing ipython-genutils (0.2.0): Downloading... 100%
#   • Installing typing-extensions (3.7.4.3): Pending...
#   • Installing zipp (3.4.1): Pending...
#   • Installing typing-extensions (3.7.4.3): Pending...
#   • Installing zipp (3.4.1): Pending...
# ...

# %%
# !gdown --id 1SL1gNj72MArEy9eMB6jI54B0Ik8O-YFU
# !gdown --id 1bu1_cB682uaSqgdjs5FVTCc4BuPGm9t4
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1SL1gNj72MArEy9eMB6jI54B0Ik8O-YFU
# To: /content/stanza 2.zip
# 100% 307M/307M [00:01<00:00, 216MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1bu1_cB682uaSqgdjs5FVTCc4BuPGm9t4
# To: /content/text_raw.zip
# 100% 16.7M/16.7M [00:00<00:00, 212MB/s]

# %%
# !unzip /content/drive/MyDrive/stanza.zip -d /content/gvdb2021-code/data/data
# Out:
# Archive:  /content/drive/MyDrive/stanza.zip
#    creating: /content/gvdb2021-code/data/data/stanza/
#   inflating: /content/gvdb2021-code/data/data/stanza/Андреев_Ангелочек.pckl
#   inflating: /content/gvdb2021-code/data/data/stanza/Андреев_Баргамот и Гараська.pckl
#   inflating: /content/gvdb2021-code/data/data/stanza/Андреев_Бездна.pckl
#   inflating: /content/gvdb2021-code/data/data/stanza/Андреев_Большой шлем.pckl
#   inflating: /content/gvdb2021-code/data/data/stanza/Андреев_В подвале.pckl
#   inflating: /content/gvdb2021-code/data/data/stanza/Андреев_В Сабурове.pckl
#   inflating: /content/gvdb2021-code/data/data/stanza/Андреев_В темную даль.pckl
#   inflating: /content/gvdb2021-code/data/data/stanza/Андреев_Валя.pckl
#   inflating: /content/gvdb2021-code/data/data/stanza/Андреев_Друг.pckl
#   inflating: /content/gvdb2021-code/data/data/stanza/Андреев_Иностранец.pckl
#   inflating: /content/gvdb2021-code/data/data/stanza/Андреев_Кусака.pckl
# ...

# %%
# !unzip /content/drive/MyDrive/text_raw.zip -d /content/gvdb2021-code/data/data
# Out:
# Archive:  /content/drive/MyDrive/text_raw.zip
#    creating: /content/gvdb2021-code/data/data/text_raw/
#   inflating: /content/gvdb2021-code/data/data/text_raw/Андреев_Ангелочек.txt
#   inflating: /content/gvdb2021-code/data/data/text_raw/Андреев_Баргамот и Гараська.txt
#   inflating: /content/gvdb2021-code/data/data/text_raw/Андреев_Бездна.txt
#   inflating: /content/gvdb2021-code/data/data/text_raw/Андреев_Большой шлем.txt
#   inflating: /content/gvdb2021-code/data/data/text_raw/Андреев_В подвале.txt
#   inflating: /content/gvdb2021-code/data/data/text_raw/Андреев_В Сабурове.txt
#   inflating: /content/gvdb2021-code/data/data/text_raw/Андреев_В темную даль.txt
#   inflating: /content/gvdb2021-code/data/data/text_raw/Андреев_Валя.txt
#   inflating: /content/gvdb2021-code/data/data/text_raw/Андреев_Друг.txt
#   inflating: /content/gvdb2021-code/data/data/text_raw/Андреев_Иностранец.txt
#   inflating: /content/gvdb2021-code/data/data/text_raw/Андреев_Кусака.txt
# ...

# %%
# !rm -rf /content/gvdb2021-code/data/data/__MACOSX

# %%
# !rm -r /content/gvdb2021-code/data/data/stanza/
# Out:
# rm: cannot remove '/content/gvdb2021-code/data/data/stanza/': No such file or directory

# %%
# !cd /content/gvdb2021-code && git config --global user.email "solano.lifan2@bk.ru"
# !cd /content/gvdb2021-code && git config --global user.name "Lifanna"
# !cd /content/gvdb2021-code && git add .
# !cd /content/gvdb2021-code && git commit -m "azaza"
# Out:
# [master 5f73731] azaza
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !cd ./gvdb2021-code && poetry run dbispipeline plans/keras.py --dryrun
# Out:
# /root/.cache/pypoetry/virtualenvs/dtgrams-GUdQ5l65-py3.7/lib/python3.7/site-packages/_distutils_hack/__init__.py:30: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# 2022-02-06 20:47:53.274062: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# ru
# 2022-02-06 20:47:57,416 INFO:dbispipeline     dataloader will generate 2 runs
# Fitting 1 folds for each of 150 candidates, totalling 150 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] features__selected_model=('word_ngrams', {'vectors__ngram_range': (1, 1)}), model__batch_size=5, model__epochs=2
# ...

# %%
# !rm -r /content/gvdb2021-code/data/data/text_raw/.DS_Store
# !rm -r /content/gvdb2021-code/data/data/stanza/.DS_Store
# Out:
# rm: cannot remove '/content/gvdb2021-code/data/data/text_raw/.DS_Store': No such file or directory

# %%
import os
len(os.listdir('/content/gvdb2021-code/data/data/text_raw'))
a = []
b = []

for file in os.listdir('/content/gvdb2021-code/data/data/stanza'):
  b.append(os.path.splitext(file)[0])
  if os.path.splitext(file)[0] in a:
    # print(os.path.splitext(file)[0])
    pass
  # else:
  #   print(os.path.splitext(file)[0])

for file in os.listdir('/content/gvdb2021-code/data/data/text_raw'):
  a.append(os.path.splitext(file)[0])
  # print(os.path.splitext(file)[0])
  if os.path.splitext(file)[0] in b:
    # print(os.path.splitext(file)[0])
    pass
  else:
    print(os.path.splitext(file)[0])


# e = set(a) & set(b)
# print(len(a), len(b))
# Out:
# Карамзин_От издателя к читателям

# %%
# !rm -rf /content/gvdb2021-code/data/data/stanza
# !rm -rf /content/gvdb2021-code/data/data/text_raw

# %%
import pandas as pd

df = pd.read_csv('/content/gvdb2021-code/data/data/dataset.csv')
df.drop(df.loc[df['text_raw']== 'text_raw/Карамзин_От издателя к читателям.txt'].index, inplace=True)
df.to_csv('/content/gvdb2021-code/data/data/dataset.csv')
